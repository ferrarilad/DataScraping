# %%
import numpy as np
from bs4 import BeautifulSoup
import urllib
import os
import pandas as pd
from requests import get
from contextlib import closing
import re

# %%
URL = "https://www.automobile.it/milano-alfa-romeo-147-1-9-mtj-120cv/127659985"
HTML = simple_get(URL)
soup = BeautifulSoup(HTML)

# %%
data = pd.read_csv("full_car_df.csv")
data.head(10)
# Out:
#    Unnamed: 0                                       Airbag  \
# 0           0  Airbag anteriori e laterali e di altro tipo
# 1           1  Airbag anteriori e laterali e di altro tipo
# 2           2  Airbag anteriori e laterali e di altro tipo
# 3           3  Airbag anteriori e laterali e di altro tipo
# 4           4  Airbag anteriori e laterali e di altro tipo
# 5           5  Airbag anteriori e laterali e di altro tipo
# 6           6                                          NaN
# 7           7  Airbag anteriori e laterali e di altro tipo
# 8           8  Airbag anteriori e laterali e di altro tipo
# 9           9                            Airbag conducente
#
#               Allestimento             Assetto           Carrozzeria  \
# 0              Mini Cooper  ['Cerchi in lega']               Berlina
# 1                        -  ['Cerchi in lega']               Berlina
# 2                        -  ['Cerchi in lega']               Berlina
# ...

# %%
out = data[data.Id==131550856].DataLink

# %%
keys = [el.text for el in table.find_all(class_="vehicle__features__title")]

# %%
out.values[0]
# Out:
# '/robecco-sul-naviglio-mercedes-benz-200-automatic-sport/131550856'

# %%
table=soup.find("table")
rows = table.find_all("tr")
dotazione = {}
for row in rows:
    cols = row.find_all("td")
    for col in cols:
        if col["class"][-1]=="table__cell--label":
            key = col.text
        if col["class"][-1]=="table__cell--value":
            feat = col.text.strip("\n")
    dotazione[key]=feat

# %%
dotazione
# Out:
# {'Tipologia': 'Usato',
#  'Marca': 'ALFA ROMEO',
#  'Modello': '147',
#  'Allestimento': '-',
#  'Cilindrata': '4 cm³',
#  'Posti': '5 posti',
#  'Numero di porte': '4 o 5 porte',
#  'Climatizzazione': 'Climatizzatore manuale',
#  'Colore': 'Blu',
#  'In grado di viaggiare': 'Sì',
#  'Carrozzeria': 'Berlina',
#  'Airbag': 'Airbag anteriori e laterali e di altro tipo'}

# %%
AUTOMOBILE_FRONTPAGE = 'https://www.automobile.it/'
pt1 = 'usate/'
pt2 ='?dove=milano_comune'
pt3 = '&immatricolazione=2005'
pt4 = '&km_max=350000_km'
pt5 = '&prezzo_a=100000'
pt6 = '&tipo_di_usato=aziendale,dimostrativo'

# %%
URL = "https://www.automobile.it/milano-alfa-romeo-147-1-9-mtj-120cv/127659985"
HTML = simple_get(URL)
soup = BeautifulSoup(HTML)
soup
# Out:
# <!DOCTYPE html>
# <html lang="it" xmlns:esi="http://www.edge-delivery.org/esi/1.0">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Alfa Romeo 147 1.9 Mtj 120cv usata 139.000 Km, 2.200 €, a Milano - 127659985 - automobile.it</title>
# <meta content="Occasione Auto usata Alfa Romeo 147 1.9 Mtj 120cv. Consulta foto e dati tecnici del veicolo e contatta il venditore in un clic!" name="description"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <link href="//s.annuncicdn.it/css/style.min.css?v=master-20181105163643-0163" rel="stylesheet"/>
# <link href="/static/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="CU_53MO-14np6I0WV9I1jsZ9nEwkk7d_AJEXEFkbD50" name="google-site-verification"/>
# <meta content="1694dfae-f612-4d69-b94d-ceb73ba0599f" name="_csrf"/>
# <script src="//s.annuncicdn.it/js/polyfills.js?v=master-20181105163643-0163"></script>
# <!--Prebid-->
# ...

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])


df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11']},
                    index=[8, 9, 10, 11])
  

frames = [df1, df2, df3]

result = pd.concat(frames,sort=False)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8  NaN
# 9    A9   B9   C9  NaN
# 10  A10  B10  C10  NaN
# 11  A11  B11  C11  NaN

# %%
results_per_page = soup.find_all(class_="search-item__body")

# %%
img_link = "http:"+results_per_page[0].find(class_="search-item__pictures__container")["style"].split("url(")[-1][:-1]
img_link
# Out:
# 'http://img1.annuncicdn.it/fd/6b/fd6b7e492dd395e3802a6dd3d9e44057_med.jpg'

# %%
img_url = "http://img1.annuncicdn.it/fd/6b/fd6b7e492dd395e3802a6dd3d9e44057_med.jpg"

import shutil

response = get(img_url, stream=True)
with open('img.png', 'wb') as out_file:
    shutil.copyfileobj(response.raw, out_file)
del response

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
# imports 
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options

# %%
WHATSAPPWEB_FRONTPAGE = "https://web.whatsapp.com/"
chromedriver = "/Users/Luca/Documents/Python/chromedriver"

# %%
opts = Options()
browser = Chrome(options=opts,executable_path = chromedriver)
browser.get(WHATSAPPWEB_FRONTPAGE)

# %%
print(browser.title)
# Out:
# WhatsApp

# %%
out = browser.find_element_by_class_name("_1jjYO")

# %%
out
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="db27281defb80c5c81ea1c758fa4d647", element="0.4970623452257057-4")>

# %%
browser.close()
